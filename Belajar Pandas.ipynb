# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl

# %%
data = pd.read_csv('sales_data.csv')

# %%
data.head(3)
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
#
#    Revenue
# 0      950
# 1      950
# 2     2401

# %%
data.describe().T
# Out:
#                    count         mean          std     min     25%     50%  \
# Day             113036.0    15.665753     8.781567     1.0     8.0    16.0
# Year            113036.0  2014.401739     1.272510  2011.0  2013.0  2014.0
# Customer_Age    113036.0    35.919212    11.021936    17.0    28.0    35.0
# Order_Quantity  113036.0    11.901660     9.561857     1.0     2.0    10.0
# Unit_Cost       113036.0   267.296366   549.835483     1.0     2.0     9.0
# Unit_Price      113036.0   452.938427   922.071219     2.0     5.0    24.0
# Profit          113036.0   285.051665   453.887443   -30.0    29.0   101.0
# Cost            113036.0   469.318695   884.866118     1.0    28.0   108.0
# Revenue         113036.0   754.370360  1309.094674     2.0    63.0   223.0
#
#                    75%      max
# Day               23.0     31.0
# Year            2016.0   2016.0
# Customer_Age      43.0     87.0
# Order_Quantity    20.0     32.0
# Unit_Cost         42.0   2171.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data.shape
# Out:
# (113036, 18)

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Date',
#  'Day',
#  'Month',
#  'Year',
#  'Customer_Age',
#  'Age_Group',
#  'Customer_Gender',
#  'Country',
#  'State',
#  'Product_Category',
#  'Sub_Category',
#  'Product',
#  'Order_Quantity',
#  'Unit_Cost',
#  'Unit_Price',
#  'Profit',
#  'Cost',
#  'Revenue']

# %%
data2 = data.copy()
data2.loc[2:5, 'Day'] = None
data2.head(7)
# Out:
#          Date   Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26  26.0  November  2013            19     Youth (<25)
# 1  2015-11-26  26.0  November  2015            19     Youth (<25)
# 2  2014-03-23   NaN     March  2014            49  Adults (35-64)
# 3  2016-03-23   NaN     March  2016            49  Adults (35-64)
# 4  2014-05-15   NaN       May  2014            47  Adults (35-64)
# 5  2016-05-15   NaN       May  2016            47  Adults (35-64)
# 6  2014-05-22  22.0       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 4

# %%
data.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data.sort_values('Order_Quantity', ascending=False)
data.head(5)
# Out:
#          Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0  2015-08-06    6     August  2015            50        Adults (35-64)
# 1  2015-11-15   15   November  2015            27  Young Adults (25-34)
# 2  2015-07-26   26       July  2015            25  Young Adults (25-34)
# 3  2015-12-28   28   December  2015            42        Adults (35-64)
# 4  2015-09-14   14  September  2015            19           Youth (<25)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               M         Canada  British Columbia      Accessories
# 1               F      Australia          Victoria         Clothing
# 2               M      Australia   New South Wales      Accessories
# 3               M  United States        Washington         Clothing
# 4               F  United States            Oregon      Accessories
#
#         Sub_Category                         Product  Order_Quantity  \
# ...

# %%
data.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head(3)
# Out:
#          Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0  2015-08-06    6    August  2015            50        Adults (35-64)
# 1  2015-11-15   15  November  2015            27  Young Adults (25-34)
# 2  2015-07-26   26      July  2015            25  Young Adults (25-34)
#
#   Customer_Gender    Country             State Product_Category  \
# 0               M     Canada  British Columbia      Accessories
# 1               F  Australia          Victoria         Clothing
# 2               M  Australia   New South Wales      Accessories
#
#         Sub_Category                Product  Order_Quantity  Unit_Cost  \
# 0            Fenders  Fender Set - Mountain              32          8
# 1             Gloves  Half-Finger Gloves, M              32          9
# 2  Bottles and Cages  Water Bottle - 30 oz.              32          2
#
#    Unit_Price  Profit  Cost  Revenue
# 0          22     441   256      697
# 1          24     319   288      607
# ...

# %%
product_revenue = data[['Product', 'Revenue']]  # Memilih kolom 'Product' dan 'Revenue'
product_revenue_sorted = product_revenue.sort_values(by='Revenue', ascending=False) # Mengurutkan berdasarkan 'Revenue' secara descending
product_revenue_sorted.head(5) # Mengambil 5 baris teratas
# Out:
#                        Product  Revenue
# 3189   Touring-1000 Yellow, 50    58074
# 10063  Touring-1000 Yellow, 50    54069
# 76267         Road-150 Red, 48    14312
# 76904         Road-150 Red, 56    14169
# 77056         Road-150 Red, 62    14169

# %%
ax = product_revenue_sorted.head().plot.bar('Product','Revenue')
ax.set_ylabel('Revenue')
ax.set_xlabel('Product')
product_revenue_sorted.head()
# Out:
#                        Product  Revenue
# 3189   Touring-1000 Yellow, 50    58074
# 10063  Touring-1000 Yellow, 50    54069
# 76267         Road-150 Red, 48    14312
# 76904         Road-150 Red, 56    14169
# 77056         Road-150 Red, 62    14169

# %%
ax = product_revenue_sorted.tail().plot.bar('Product','Revenue')
ax.set_ylabel('Revenue')
ax.set_xlabel('Product')

product_revenue_sorted.tail()
# Out:
#                     Product  Revenue
# 111562  Patch Kit/8 Patches        2
# 93114   Patch Kit/8 Patches        2
# 93988   Patch Kit/8 Patches        2
# 93976   Patch Kit/8 Patches        2
# 111577  Patch Kit/8 Patches        2

# %%
data.head(3)
# Out:
#          Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0  2015-08-06    6    August  2015            50        Adults (35-64)
# 1  2015-11-15   15  November  2015            27  Young Adults (25-34)
# 2  2015-07-26   26      July  2015            25  Young Adults (25-34)
#
#   Customer_Gender    Country             State Product_Category  \
# 0               M     Canada  British Columbia      Accessories
# 1               F  Australia          Victoria         Clothing
# 2               M  Australia   New South Wales      Accessories
#
#         Sub_Category                Product  Order_Quantity  Unit_Cost  \
# 0            Fenders  Fender Set - Mountain              32          8
# 1             Gloves  Half-Finger Gloves, M              32          9
# 2  Bottles and Cages  Water Bottle - 30 oz.              32          2
#
#    Unit_Price  Profit  Cost  Revenue
# 0          22     441   256      697
# 1          24     319   288      607
# ...

# %%
data.loc[1]
# Out:
# Date                           2015-11-15
# Day                                    15
# Month                            November
# Year                                 2015
# Customer_Age                           27
# Age_Group            Young Adults (25-34)
# Customer_Gender                         F
# Country                         Australia
# State                            Victoria
# Product_Category                 Clothing
# Sub_Category                       Gloves
# Product             Half-Finger Gloves, M
# Order_Quantity                         32
# Unit_Cost                               9
# Unit_Price                             24
# Profit                                319
# Cost                                  288
# Revenue                               607
# Name: 1, dtype: object

# %%
data.loc[[10, 20, 30]]
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 10  2016-05-07    7        May  2016            30  Young Adults (25-34)
# 20  2015-09-22   22  September  2015            22           Youth (<25)
# 30  2015-09-19   19  September  2015            36        Adults (35-64)
#
#    Customer_Gender        Country       State Product_Category  \
# 10               F  United States  California      Accessories
# 20               M  United States      Oregon      Accessories
# 30               M  United States  California      Accessories
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# 10  Tires and Tubes      Patch Kit/8 Patches              32          1
# 20  Tires and Tubes        Touring Tire Tube              32          2
# 30          Helmets  Sport-100 Helmet, Black              32         13
#
#     Unit_Price  Profit  Cost  Revenue
# 10           2      31    32       63
# 20           5      74    64      138
# ...

# %%
data.head()
# Out:
#          Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0  2015-08-06    6     August  2015            50        Adults (35-64)
# 1  2015-11-15   15   November  2015            27  Young Adults (25-34)
# 2  2015-07-26   26       July  2015            25  Young Adults (25-34)
# 3  2015-12-28   28   December  2015            42        Adults (35-64)
# 4  2015-09-14   14  September  2015            19           Youth (<25)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               M         Canada  British Columbia      Accessories
# 1               F      Australia          Victoria         Clothing
# 2               M      Australia   New South Wales      Accessories
# 3               M  United States        Washington         Clothing
# 4               F  United States            Oregon      Accessories
#
#         Sub_Category                         Product  Order_Quantity  \
# ...

# %%
data[data.Country =='Australia'].count()
# Out:
# Date                23936
# Day                 23936
# Month               23936
# Year                23936
# Customer_Age        23936
# Age_Group           23936
# Customer_Gender     23936
# Country             23936
# State               23936
# Product_Category    23936
# Sub_Category        23936
# Product             23936
# Order_Quantity      23936
# Unit_Cost           23936
# Unit_Price          23936
# Profit              23936
# Cost                23936
# Revenue             23936
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Date                0
# Day                 4
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
data2.shape
# Out:
# (113036, 18)

# %%
data3 = data2.copy()
data3.dropna(inplace=True, axis=1)
data3.head()
# Out:
#          Date     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# 0  2013-11-26  November  2013            19     Youth (<25)               M
# 1  2015-11-26  November  2015            19     Youth (<25)               M
# 2  2014-03-23     March  2014            49  Adults (35-64)               M
# 3  2016-03-23     March  2016            49  Adults (35-64)               M
# 4  2014-05-15       May  2014            47  Adults (35-64)               F
#
#      Country             State Product_Category Sub_Category  \
# 0     Canada  British Columbia      Accessories   Bike Racks
# 1     Canada  British Columbia      Accessories   Bike Racks
# 2  Australia   New South Wales      Accessories   Bike Racks
# 3  Australia   New South Wales      Accessories   Bike Racks
# 4  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data2
# Out:
#               Date   Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26  26.0  November  2013            19     Youth (<25)
# 1       2015-11-26  26.0  November  2015            19     Youth (<25)
# 2       2014-03-23   NaN     March  2014            49  Adults (35-64)
# 3       2016-03-23   NaN     March  2016            49  Adults (35-64)
# 4       2014-05-15   NaN       May  2014            47  Adults (35-64)
# ...            ...   ...       ...   ...           ...             ...
# 113031  2016-04-12  12.0     April  2016            41  Adults (35-64)
# 113032  2014-04-02   2.0     April  2014            18     Youth (<25)
# 113033  2016-04-02   2.0     April  2016            18     Youth (<25)
# 113034  2014-03-04   4.0     March  2014            37  Adults (35-64)
# 113035  2016-03-04   4.0     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
data
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0       2015-08-06    6     August  2015            50        Adults (35-64)
# 1       2015-11-15   15   November  2015            27  Young Adults (25-34)
# 2       2015-07-26   26       July  2015            25  Young Adults (25-34)
# 3       2015-12-28   28   December  2015            42        Adults (35-64)
# 4       2015-09-14   14  September  2015            19           Youth (<25)
# ...            ...  ...        ...   ...           ...                   ...
# 113031  2014-01-08    8    January  2014            40        Adults (35-64)
# 113032  2016-01-08    8    January  2016            40        Adults (35-64)
# 113033  2014-02-09    9   February  2014            40        Adults (35-64)
# 113034  2016-02-09    9   February  2016            40        Adults (35-64)
# 113035  2013-06-12   12       June  2013            35        Adults (35-64)
#
# ...
